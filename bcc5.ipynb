# %%
#function
def msg():#called function
    print("Hello World")

msg()
# Out:
# Hello World

# %%
#function
def add():#called function
    n1 = int(input("Enter first number: "))
    n2 = int(input("Enter second number: "))
    print(n1+n2)

add()
# Out:
# Enter first number: 30
# Enter second number: 20
# 50

# %%
#how to return multiple values
def add():#called function
    n1 = int(input("Enter first number: "))
    n2 = int(input("Enter second number: "))
    sum=n1+n2
    mul=n1*n2
    sub=n1-n2
    div=n1/n2
    return sum,sub,mul,div
result=add()
print(result)
# Out:
# Enter first number: 20
# Enter second number: 10
# (30, 10, 200, 2.0)

# %%
#positional,keyword,default,variable length or variable number arguments
#Positional Argument
def personalInfo(fname,lname):
  print("First Name=",fname)
  print("Last Name=",lname)
personalInfo("Prashant","Jha")
# Out:
# First Name= Prashant
# Last Name= Jha

# %%
#Keyword Argument
def personalInfo(fname,lname):
  print("First Name=",fname)
  print("Last Name=",lname)
fname="Prashant"
lname="Jha"
personalInfo(fname,lname)
# Out:
# First Name= Prashant
# Last Name= Jha

# %%
def cityName(city="Unknown"):
  print(city)

cityName("Delhi")
cityName("Mumbai")
cityName()
# Out:
# Delhi
# Mumbai
# Unknown

# %%
#Variable length argument
def studentNames(*name):
    print(name)

studentNames("Prashant","Rahul","sandip","ashish")
# Out:
# ('Prashant', 'Rahul', 'sandip', 'ashish')

# %%
mylist=[5,5,9,7,5,6]
#search the element 7
def searchElement(target):
    for i in range(len(mylist)):#mylist=6
        print(mylist[i])#i=23,mylist[3]
searchElement(7)#7 this element we have to search
# Out:
# 5
# 5
# 9
# 7
# 5
# 6

# %%
mylist=[5,5,9,7,5,6]
#search the element 7
def searchElement(target):
    for i in range(len(mylist)):#mylist=6
        if target==mylist[i]:
            print("Element found at index",i)
            break

searchElement(7)#7 this element we have to search
# Out:
# Element found at index 3

# %%
mylist=[5,5,9,7,5,6]
#search the element 7
def searchElement(target):
    for i in range(len(mylist)):#mylist=6
        if target==mylist[i]:
            print("Element found at index",i)
            break

searchElement(7)#7 this element we have to search
