# %%
#why python is called dynamically typed language?
math = 40
pi = 3.14
name = 'Shreya Shrivas'
print(type(pi))
print(type(math))
print(type(name))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
#what is typecasting?
print(2+2)
print("2"+"2")

val1 = input("Enter first number: ") #this input by default takes string values
val2 = input("Enter second number:")
print(val1+val2)

val1 = int(input("Enter first number: "))
val2 = int(input("Enter second number:"))
print(val1+val2)
# Out:
# 4
# 22
# Enter first number: 2
# Enter second number:2
# 22
# Enter first number: 2
# Enter second number:2
# 4

# %%
#int() used to convert in integer
print(int(3.14))
print(int(True))
print(int(False))
print(int("4"))
# Out:
# 3
# 1
# 0
# 4

# %%
print(float(3.14))
print(float(True))
print(float(False))
print(float(4.22))
print(("4"))
# Out:
# 3.14
# 1.0
# 0.0
# 4.22
# 4

# %%
#complex() used to convert
print(complex(3.14))
print(complex(True))
print(complex(False))
print(complex("5"))
print(complex("5.6"))
print(complex(5,-3))
print(complex(True,False))
# Out:
# (3.14+0j)
# (1+0j)
# 0j
# (5+0j)
# (5.6+0j)
# (5-3j)
# (1+0j)

# %%
print(bool(0))
print(bool(15))
print(bool(0+0j))
print(bool(3.14))
print(bool(True))
print(bool(False))
print(bool("5"))
print(bool("5.6"))
print(bool(1+2j))
print(bool(-1))
print(bool())
# Out:
# False
# True
# False
# True
# True
# False
# True
# True
# True
# True
# False

# %%
#WAP for simple interest
p = 100000
roi = 10
t = 1
si = (p*roi*t)/100
print("Simple interest:",si)
# Out:
# Simple interest: 10000.0

# %%
#WAP to accept a centigrade temperature
c = float(input("Enter temperature in centigrade: "))
f = (9/5)*(c) +32
print("Temperature in Fahrenheit:",f)
# Out:
# Enter temperature in centigrade: 32.1
# Temperature in Fahrenheit: 89.78

# %%
a = 100
b = 200
a = a+b
b = a-b
a = a-b
print(a)
print(b)
print(a,b)
# Out:
# 200
# 100
# 200 100

# %%
#height
h = float(input("Enter height: "))
inch = h*12
cm = inch*2.54
print("Height in inches:",inch)
print("Height in centimeters:",cm)
# Out:
# Enter height: 23
# Height in inches: 276.0
# Height in centimeters: 701.04

# %%
#reversing 3 digit
num = 123
a = num%10
num = num // 10
b = num%10
c = num//10
rev = a*100+b*10+c*1
print(rev)
# Out:
# 321

# %%
num = 1234567

for i in range(7):
    a = num % 10
    print(a,end=" ")
    num = num // 10
# Out:
# 7 6 5 4 3 2 1
