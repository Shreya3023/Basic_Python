# %%
n=int(input("enter value1:"))
m=int(input("Enter Value2:"))
v=int(input("Enter Value3:"))

if n>m:
    if n>v:
        print("n is greater")
    else:
        print("v is greater")
else:
    if m>v:
        print("m is greater")
    else:
        print("v is greater")
# Out:
# enter value1:2
# Enter Value2:22
# Enter Value3:122
# v is greater

# %%
n=int(input("enter value1:"))
m=int(input("Enter Value2:"))
v=int(input("Enter Value3:"))

per=(n+m+v)/300*100
print(per)

if per>=90:
    print("A")
elif per>=80 and per<90:
    print('B')
elif per>=60 and per<80:
    print('C')
else:
    print("FAIL")
# Out:
# enter value1:1
# Enter Value2:1
# Enter Value3:11
# 4.333333333333334
# FAIL

# %%
mydict={
    'name':'Namrata',
    'professional':'Developer',
    'empid':1002
}

print(mydict)
print(type(mydict))
# Out:
# {'name': 'Namrata', 'professional': 'Developer', 'empid': 1002}
# <class 'dict'>

# %%
a=mydict[102]
print(a)
# Out:
# Riya

# %%
mydict[102]='Shreya'
print(mydict)
# Out:
# {101: 'Riya', 102: 'Shreya', '103': 'Shweta', '104': 'Neha', 104: 'Riya'}

# %%
for x in mydict:
    print(x)
# Out:
# 101
# 102
# 103
# 104
# 104

# %%
for x in mydict.values():
    print(x)
# Out:
# Riya
# Shreya
# Shweta
# Neha
# Riya

# %%
for x,y in mydict.items():
    print(x,y)
# Out:
# 101 Riya
# 102 Shreya
# 103 Shweta
# 104 Neha
# 104 Riya

# %%
mydict['mobile_no']=4646478
print(mydict)
# Out:
# {101: 'Riya', 102: 'Shreya', '103': 'Shweta', '104': 'Neha', 104: 'Riya', 'mobile_no': 4646478}

# %%
mydict={
    101:'namrata',
    'professional':'developer',
    'empid':101
}

mydict.pop("empid")
print(mydict)
# Out:
# {101: 'namrata', 'professional': 'developer'}

# %%
name='prashantjha'

print(name[0])
print(name[1])
print(name[-1])
print(name[0:5])
print(name[1:])
print(name[:5])
print(name[:])
print(name[1:8:2])
print(name[::-1])
# Out:
# p
# r
# a
# prash
# rashantjha
# prash
# prashantjha
# rsat
# ahjtnahsarp

# %%
s='help4code is best platform for practicing programming'

print(s.find('help4code'))
print(s.find('python'))
print(s.find('programming'))
# Out:
# 0
# -1
# 42

# %%
s=('namrata','ashish','sandip')
m='|'.join(s)

print(m)
# Out:
# namrata|ashish|sandip

# %%
s='Python is a high level programming language'

print(s.lower())
print(s.upper())
print(s.swapcase())
print(s.title())
print(s.capitalize())
# Out:
# python is a high level programming language
# PYTHON IS A HIGH LEVEL PROGRAMMING LANGUAGE
# pYTHON IS A HIGH LEVEL PROGRAMMING LANGUAGE
# Python Is A High Level Programming Language
# Python is a high level programming language

# %%
print('Subjects marks:')

p=50
c=60
m=70

print('Pysics ={} chem ={} math={}'.format(p,c,m))
print('Pysics ={0} chem ={1} math={2}'.format(p,c,m))
print('Pysics ={x} chem ={y} math={z}'.format(x=p,y=c,z=m))

total=p+c+m

print("Total Marks",f"{total}")
print("Roll No","7".zfill(4))
# Out:
# Subjects marks:
# Pysics =50 chem =60 math=70
# Pysics =50 chem =60 math=70
# Pysics =50 chem =60 math=70
# Total Marks 180
# Roll No 0007

# %%
print('prashantjha777'.isalnum())
print('prashantjha'.isalpha())
print('777f'.isdigit())
print('sdsdsd'.islower())
print(''.islower())
print("PRASHANTj".isupper())
print('My Name Is Prashant'.istitle())
print(''.istitle())
print(''.isspace())
print("hello".startswith("He"))
print("Hello".endswith('lo'))
# Out:
# True
# True
# False
# True
# False
# False
# True
# False
# False
# False
# True

# %%
a=50
b=30
c=20
d=10

print((a+b)*c/d)
print((a-b)*(c/d))
print(a+(b*c)/d)
# Out:
# 160.0
# 40.0
# 110.0

# %%
x=['A','B','C']
y=['A','B','C']
z=[1,2,3,4]

print(x==y)
print(x==z)
print(x!=z)
# Out:
# True
# False
# True

# %%
name='prashant'

for i in name:
    print(i)
# Out:
# p
# r
# a
# s
# h
# a
# n
# t

# %%
name='prashant'

data=['a','e','i','o','u']
vowels=0
con=0

for i in name:
    if i in data:
        vowels+=1
    else:
        con+=1

print(vowels)
print(con)
# Out:
# 2
# 6
